# %%
import sqlalchemy
import pandas as pd
import json

# %%
config = json.load(open('../config/configsql.json', 'r'))

# %%
user = config['dev']['mysql']['user']
password = config['dev']['mysql']['password']
host = config['dev']['mysql']['host']
port = config['dev']['mysql']['port']
dbname = config['dev']['mysql']['dbname']

# %%
template = "mysql+pymysql://{user}:{password}@{host}:{port}/{dbname}"
connection_string = template.format(user=user, password=password, host=host, port=port, dbname=dbname)

# %%
conn = sqlalchemy.create_engine(connection_string, pool_size=1)

# %%
df = pd.read_sql("SELECT * from blog order by blog_id desc limit 10", conn)
df.head()
# Out:
#    blog_id                                         prettyname  \
# 0      341              /episodes/2018/reinforcement-learning
# 1      340             /meta/2018/data-skeptic-t-shirt-sizing
# 2      338           /projects/2018/beer-in-hand-data-science
# 3      334            /episodes/2018/evolutionary-computation
# 4      333  /bonus/2018/deploying-machine-learning-to-prod...
#
#                                                title  author  \
# 0                             Reinforcement Learning    Kyle
# 1                        Data Skeptic T-Shirt Sizing    Kyle
# 2                          Beer-in-Hand Data Science  Amanda
# 3                           Evolutionary Computation    Kyle
# 4  Deploying Machine Learning to Production with ...    Kyle
#
#                                             abstract        date_created  \
# 0  In many real world situations, a person/agent ... 2018-02-09 07:05:02
# 1  We've gotten some questions about the manufact... 2018-02-05 17:19:51
# 2  The main question this analysis is meant to ta... 2018-02-05 05:00:30
# 3  In this weeks episode, Kyle is joined by Rist... 2018-01-31 22:41:50
# 4  A dirty secret of machine learning in industry... 2018-01-29 17:03:55
#
#   publish_date       last_rendered  \
# 0   2018-02-08 2018-02-09 07:05:02
# 1   2018-01-01 2018-02-05 17:22:55
# 2   2018-02-05 2018-02-05 06:33:23
# 3   2018-02-02 2018-02-02 05:16:39
# 4   2018-01-29 2018-01-29 17:03:55
#
#                                             src_file  \
# 0           episodes/2018/reinforcement-learning.htm
# 1                        meta/2018/t-shirt-sizes.htm
# 2        projects/2018/beer-in-hand-data-science.htm
# 3         episodes/2018/evolutionary-computation.htm
# 4  bonus/2018/deploying-machine-learning-to-produ...
#
#                              c_hash                              guid  \
# 0  02aa89ea6ff01451a44aaa67e7be1e48  f8946083c7765a945920e2a56db49f4c
# 1  0acd68f75a2c1ec8cd9eb3cc021bb518
# 2  8c2250a019faea7fc4dc669fd7ea65cc
# 3  a9a4a214d34ee2ba0eec22bf2109a386  1b97492aaad0bc3ca0f32e7e8fd75488
# 4  898b817da66062cfb2820274a507aa40
#
#   member_link        last_indexed
# 0             2018-02-09 20:54:06
# 1             2018-02-09 20:54:05
# 2             2018-02-09 20:54:04
# 3             2018-02-09 20:54:04
# 4             2018-02-09 20:54:03
